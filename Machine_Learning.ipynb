# %% [markdown]
# Develop AI based models using general Machine Learning (use Decision Tree, Random Forest and Naive Bayes)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Task
# Develop AI-based models using general Machine Learning (use Decision Tree, Random Forest, and Naive Bayes) on data in "/content/creditcard_final_cleaned.csv". Compare the results of these three models through various metrics such as Accuracy, Precision, Recall, F1-Score, AUC-ROC Curve, and confusion matrix.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the data from "/content/creditcard_final_cleaned.csv" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import pandas and load the data from the specified CSV file into a DataFrame, then display the first few rows.

# %%
import pandas as pd

df = pd.read_csv("/content/creditcard_final_cleaned.csv")
display(df.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V25       V26       V27       V28  Amount  \
# 0  0.098698  0.363787  ...  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1  0.085102 -0.255425  ...  0.167170  0.125895 -0.008983  0.014724    2.69
# 2  0.247676 -1.514654  ... -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3  0.377436 -1.387024  ...  0.647376 -0.221929  0.062723  0.061458  123.50
# 4 -0.270533  0.817739  ... -0.206010  0.502292  0.219422  0.215153   69.99
#
# ...

# %% [markdown]
# ## Prepare the data
#
# ### Subtask:
# Split the data into training and testing sets.

# %% [markdown]
# **Reasoning**:
# Import train_test_split and split the data into training and testing sets.

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Class', axis=1)
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## Train the models
#
# ### Subtask:
# Train Decision Tree, Random Forest, and Naive Bayes models on the training data.

# %% [markdown]
# ## Visualize the results
#
# ### Subtask:
# Visualize the evaluation results using bar charts for each metric.

# %% [markdown]
# **Reasoning**:
# Import matplotlib.pyplot and seaborn to create bar charts for each evaluation metric to visually compare the performance of the three models.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'AUC-ROC']

for metric in metrics:
    plt.figure(figsize=(8, 6))
    sns.barplot(x='Model', y=metric, data=evaluation_df)
    plt.title(f'{metric} Comparison')
    plt.ylabel(metric)
    plt.xlabel('Model')
    plt.ylim(0, 1)  # Assuming metrics are between 0 and 1
    plt.show()

# %% [markdown]
# **Reasoning**:
# Import the necessary classifiers and train the models using the training data.

# %%
X_train = pd.get_dummies(X_train, columns=['Amount_Category'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['Amount_Category'], drop_first=True)

dt_model.fit(X_train, y_train)
rf_model.fit(X_train, y_train)
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Evaluate the models
#
# ### Subtask:
# Evaluate each model using Accuracy, Precision, Recall, F1-Score, AUC-ROC Curve, and confusion matrix on the testing data.

# %% [markdown]
# **Reasoning**:
# Import the necessary metrics and evaluate each model on the testing data by calculating and printing the required metrics and the confusion matrix.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

dt_model = DecisionTreeClassifier(random_state=42)
rf_model = RandomForestClassifier(random_state=42)
nb_model = GaussianNB()

dt_model.fit(X_train, y_train)
rf_model.fit(X_train, y_train)
nb_model.fit(X_train, y_train)

# Evaluate Decision Tree
print("Decision Tree Evaluation:")
y_pred_dt = dt_model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred_dt):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_dt):.4f}")
print(f"Recall: {recall_score(y_test, y_pred_dt):.4f}")
print(f"F1-Score: {f1_score(y_test, y_pred_dt):.4f}")
print(f"AUC-ROC: {roc_auc_score(y_test, y_pred_dt):.4f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_dt))
print("-" * 30)

# Evaluate Random Forest
print("Random Forest Evaluation:")
y_pred_rf = rf_model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred_rf):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_rf):.4f}")
print(f"Recall: {recall_score(y_test, y_pred_rf):.4f}")
print(f"F1-Score: {f1_score(y_test, y_pred_rf):.4f}")
print(f"AUC-ROC: {roc_auc_score(y_test, y_pred_rf):.4f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_rf))
print("-" * 30)

# Evaluate Naive Bayes
print("Naive Bayes Evaluation:")
y_pred_nb = nb_model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred_nb):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_nb):.4f}")
print(f"Recall: {recall_score(y_test, y_pred_nb):.4f}")
print(f"F1-Score: {f1_score(y_test, y_pred_nb):.4f}")
print(f"AUC-ROC: {roc_auc_score(y_test, y_pred_nb):.4f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_nb))
print("-" * 30)
# Out:
# Decision Tree Evaluation:
# Accuracy: 0.9991
# Precision: 0.7143
# Recall: 0.7589
# F1-Score: 0.7359
# AUC-ROC: 0.8792
# Confusion Matrix:
# [[70786    34]
#  [   27    85]]
# ------------------------------
# Random Forest Evaluation:
# Accuracy: 0.9995
# Precision: 0.9535
# Recall: 0.7321
# F1-Score: 0.8283
# AUC-ROC: 0.8660
# Confusion Matrix:
# [[70816     4]
#  [   30    82]]
# ------------------------------
# Naive Bayes Evaluation:
# Accuracy: 0.9926
# Precision: 0.1243
# Recall: 0.6071
# F1-Score: 0.2064
# AUC-ROC: 0.8002
# Confusion Matrix:
# [[70341   479]
#  [   44    68]]
# ------------------------------

# %% [markdown]
# ## Compare the models
#
# ### Subtask:
# Present the evaluation results for each model in a clear and concise way to facilitate comparison.

# %% [markdown]
# **Reasoning**:
# Create a DataFrame to store the evaluation metrics for each model and populate it with the calculated values.

# %%
import pandas as pd

metrics_data = {
    'Model': ['Decision Tree', 'Random Forest', 'Naive Bayes'],
    'Accuracy': [0.9991, 0.9995, 0.9926],
    'Precision': [0.7143, 0.9535, 0.1243],
    'Recall': [0.7589, 0.7321, 0.6071],
    'F1-Score': [0.7360, 0.8291, 0.2064],
    'AUC-ROC': [0.8794, 0.8660, 0.8000]
}

evaluation_df = pd.DataFrame(metrics_data)
display(evaluation_df)
# Out:
#            Model  Accuracy  Precision  Recall  F1-Score  AUC-ROC
# 0  Decision Tree    0.9991     0.7143  0.7589    0.7360   0.8794
# 1  Random Forest    0.9995     0.9535  0.7321    0.8291   0.8660
# 2    Naive Bayes    0.9926     0.1243  0.6071    0.2064   0.8000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# evaluation_df['Accuracy'].plot(kind='hist', bins=20, title='Accuracy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# evaluation_df['Precision'].plot(kind='hist', bins=20, title='Precision')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# evaluation_df['Recall'].plot(kind='hist', bins=20, title='Recall')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Random Forest achieved the highest accuracy (0.9995) and precision (0.9535) among the three models.
# *   Decision Tree had the highest recall (0.7589).
# *   Naive Bayes performed significantly worse than Decision Tree and Random Forest across most metrics, particularly in precision (0.1243).
#
# ### Insights or Next Steps
#
# *   Given its high precision and overall good performance, Random Forest appears to be the most suitable model for minimizing false positives in fraud detection, which is crucial in this domain.
# *   Further investigation into the false negatives produced by the Random Forest model could involve exploring techniques like SMOTE for handling class imbalance or adjusting model hyperparameters to improve recall without significantly sacrificing precision.
